# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.set_style("darkgrid")

# %%
fig, ax = plt.subplots(3,3,figsize=(20,20))
plt.close(fig)

# %%
penguins = sns.load_dataset("penguins")
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack",ax=ax[1,1]);

# %%
fig

# %%
a = sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack",col="sex",row="species");

# %%
a.axes
# Out:
# array([[<AxesSubplot:title={'center':'species = Adelie | sex = Male'}, ylabel='Count'>,
#         <AxesSubplot:title={'center':'species = Adelie | sex = Female'}>],
#        [<AxesSubplot:title={'center':'species = Chinstrap | sex = Male'}, ylabel='Count'>,
#         <AxesSubplot:title={'center':'species = Chinstrap | sex = Female'}>],
#        [<AxesSubplot:title={'center':'species = Gentoo | sex = Male'}, xlabel='flipper_length_mm', ylabel='Count'>,
#         <AxesSubplot:title={'center':'species = Gentoo | sex = Female'}, xlabel='flipper_length_mm'>]],
#       dtype=object)

# %%
isinstance(a,matplotlib.figure.Figure)
# Out:
# False

# %%
type(plt.figure())
# Out:
# matplotlib.figure.Figure

# %%
sns.pairplot(data=penguins)

# %%
with sns.axes_style("darkgrid"):
    sns.pairplot(data=penguins)
